# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split

# %%
w_data = pd.read_csv('./Data/daily_data.csv')

# %%
w_data
# Out:
#      day_id city_id  temperature_celsius           condition_text  wind_kph  \
# 0     D0001    C001                 27.0                      NaN       6.1
# 1     D0002    C001                 22.0                      NaN       6.1
# 2     D0003    C001                 20.0  Light Rain with Thunder       3.6
# 3     D0004    C001                 17.0          Clear and Sunny       6.1
# 4     D0005    C001                 18.0                      NaN       3.6
# ...     ...     ...                  ...                      ...       ...
# 2888  D2889    C112                 17.1          Clear and Sunny      13.3
# 2889  D2890    C112                 17.4                      NaN      13.0
# 2890  D2891    C112                 19.2                      NaN      11.5
# 2891  D2892    C112                 19.2                      NaN      14.4
# 2892  D2893    C112                 18.6                      NaN      17.3
#
#       wind_degree  pressure_mb  precip_mm  humidity  cloud  \
# 0             210       1006.0        0.0        54     75
# 1             170       1006.0        0.0        73     75
# 2              10       1011.0        4.5       100     75
# 3             150       1018.0        0.0        88      0
# 4              92       1019.0        0.0        94      0
# ...           ...          ...        ...       ...    ...
# 2888           61       1017.0        0.0        57      3
# 2889           51       1017.0        0.0        49      0
# 2890           46       1016.0        0.0        34      0
# 2891           76       1017.0        0.0        45      2
# 2892           61       1016.0        0.0        34      0
#
#       feels_like_celsius  visibility_km  uv_index  gust_kph  \
# 0                   28.0           10.0       6.0      11.9
# 1                   24.5           10.0       1.0      23.4
# 2                   20.0           10.0       1.0      12.6
# 3                   17.0           10.0       1.0      11.2
# 4                   18.0           10.0       1.0       9.0
# ...                  ...            ...       ...       ...
# 2888                17.1           10.0       1.0      22.2
# 2889                17.4           10.0       1.0      22.2
# 2890                19.2           10.0       1.0      21.3
# 2891                19.2           10.0       1.0      24.9
# 2892                18.6           10.0       1.0      30.2
#
#       air_quality_us-epa-index   sunrise    sunset
# 0                            2  06:04 AM  07:19 PM
# 1                            1  06:05 AM  07:18 PM
# 2                            1  06:05 AM  07:18 PM
# 3                            1  06:06 AM  07:16 PM
# 4                            1  06:07 AM  07:15 PM
# ...                        ...       ...       ...
# 2888                         1  05:49 AM  05:51 PM
# 2889                         1  05:49 AM  05:52 PM
# 2890                         2  05:48 AM  05:52 PM
# 2891                         2  05:47 AM  05:52 PM
# 2892                         2  05:46 AM  05:52 PM
#
# [2893 rows x 17 columns]

# %%
train_dt = w_data[w_data['condition_text'].notnull()].copy()
test_dt = w_data[w_data['condition_text'].isnull()].copy()
print(train_dt.shape, test_dt.shape)
# Out:
# (479, 17) (2414, 17)

# %%
conds = train_dt['condition_text'].unique()

cond_ids = {}
i = 0

for cond in conds:
    cond_ids[cond] = i
    i += 1

cond_ids
# Out:
# {'Light Rain with Thunder': 0,
#  'Clear and Sunny': 1,
#  'Partly Cloudy': 2,
#  'Light Precipitation': 3,
#  'Cloudy and Overcast': 4,
#  'Mist or Fog': 5,
#  'Rain Showers': 6,
#  'Moderate to Heavy Rain': 7,
#  'Thunderstorms': 8}

# %%
cond_strngs = {v: k for k, v in cond_ids.items()}
cond_strngs
# Out:
# {0: 'Light Rain with Thunder',
#  1: 'Clear and Sunny',
#  2: 'Partly Cloudy',
#  3: 'Light Precipitation',
#  4: 'Cloudy and Overcast',
#  5: 'Mist or Fog',
#  6: 'Rain Showers',
#  7: 'Moderate to Heavy Rain',
#  8: 'Thunderstorms'}

# %%
train_dt.loc[:, 'condition_id'] = train_dt['condition_text'].apply(lambda x: cond_ids[x])
train_dt
# Out:
#      day_id city_id  temperature_celsius           condition_text  wind_kph  \
# 2     D0003    C001                 20.0  Light Rain with Thunder       3.6
# 3     D0004    C001                 17.0          Clear and Sunny       6.1
# 6     D0007    C001                 21.0            Partly Cloudy       4.0
# 18    D0019    C001                 19.0          Clear and Sunny       3.6
# 27    D0028    C002                 19.0            Partly Cloudy       3.6
# ...     ...     ...                  ...                      ...       ...
# 2838  D2839    C110                 27.0            Partly Cloudy      19.1
# 2863  D2864    C111                 21.4      Light Precipitation       3.6
# 2873  D2874    C112                 16.9          Clear and Sunny      16.6
# 2886  D2887    C112                 19.5          Clear and Sunny       5.4
# 2888  D2889    C112                 17.1          Clear and Sunny      13.3
#
#       wind_degree  pressure_mb  precip_mm  humidity  cloud  \
# 2              10       1011.0       4.50       100     75
# 3             150       1018.0       0.00        88      0
# 6             310       1015.0       0.00       100     50
# 18             64       1017.0       0.00        88      0
# 27             83       1010.0       0.00        73     25
# ...           ...          ...        ...       ...    ...
# 2838           90       1014.0       0.01        70     25
# 2863          178       1012.0       0.00        89     75
# 2873           68       1018.0       0.00        44      2
# 2886           27       1014.0       0.00        34      0
# 2888           61       1017.0       0.00        57      3
#
#       feels_like_celsius  visibility_km  uv_index  gust_kph  \
# 2                   20.0           10.0       1.0      12.6
# 3                   17.0           10.0       1.0      11.2
# 6                   21.0           10.0       1.0      15.1
# 18                  19.0           10.0       1.0       8.3
# 27                  19.0           10.0       1.0       8.3
# ...                  ...            ...       ...       ...
# 2838                29.8           10.0       6.0      45.6
# 2863                21.4           10.0       6.0       6.6
# 2873                16.9           10.0       1.0      27.0
# 2886                19.4           10.0       1.0      11.2
# 2888                17.1           10.0       1.0      22.2
#
#       air_quality_us-epa-index   sunrise    sunset  condition_id
# 2                            1  06:05 AM  07:18 PM             0
# 3                            1  06:06 AM  07:16 PM             1
# 6                            2  06:08 AM  07:11 PM             2
# 18                           3  06:20 AM  06:51 PM             1
# 27                           1  06:17 AM  07:20 PM             2
# ...                        ...       ...       ...           ...
# 2838                         1  05:39 AM  05:43 PM             2
# 2863                         1  06:17 AM  06:25 PM             3
# 2873                         1  06:02 AM  05:49 PM             1
# 2886                         2  05:51 AM  05:51 PM             1
# 2888                         1  05:49 AM  05:51 PM             1
#
# [479 rows x 18 columns]

# %%
train_dt_fil = train_dt.drop(['city_id', 'condition_text', 'sunrise', 'sunset'], axis=1).copy()
train_dt_fil.set_index('day_id', inplace=True)
train_dt_fil
# Out:
#         temperature_celsius  wind_kph  wind_degree  pressure_mb  precip_mm  \
# day_id
# D0003                  20.0       3.6           10       1011.0       4.50
# D0004                  17.0       6.1          150       1018.0       0.00
# D0007                  21.0       4.0          310       1015.0       0.00
# D0019                  19.0       3.6           64       1017.0       0.00
# D0028                  19.0       3.6           83       1010.0       0.00
# ...                     ...       ...          ...          ...        ...
# D2839                  27.0      19.1           90       1014.0       0.01
# D2864                  21.4       3.6          178       1012.0       0.00
# D2874                  16.9      16.6           68       1018.0       0.00
# D2887                  19.5       5.4           27       1014.0       0.00
# D2889                  17.1      13.3           61       1017.0       0.00
#
#         humidity  cloud  feels_like_celsius  visibility_km  uv_index  \
# day_id
# D0003        100     75                20.0           10.0       1.0
# D0004         88      0                17.0           10.0       1.0
# D0007        100     50                21.0           10.0       1.0
# D0019         88      0                19.0           10.0       1.0
# D0028         73     25                19.0           10.0       1.0
# ...          ...    ...                 ...            ...       ...
# D2839         70     25                29.8           10.0       6.0
# D2864         89     75                21.4           10.0       6.0
# D2874         44      2                16.9           10.0       1.0
# D2887         34      0                19.4           10.0       1.0
# D2889         57      3                17.1           10.0       1.0
#
#         gust_kph  air_quality_us-epa-index  condition_id
# day_id
# D0003       12.6                         1             0
# D0004       11.2                         1             1
# D0007       15.1                         2             2
# D0019        8.3                         3             1
# D0028        8.3                         1             2
# ...          ...                       ...           ...
# D2839       45.6                         1             2
# D2864        6.6                         1             3
# D2874       27.0                         1             1
# D2887       11.2                         2             1
# D2889       22.2                         1             1
#
# [479 rows x 13 columns]

# %%
# X = train_dt_fil.drop('condition_id', axis=1)
# y = train_dt_fil['condition_id']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# rf = RandomForestClassifier(n_estimators=80, random_state=42)
# rf.fit(X_train, y_train)

# y_pred = rf.predict(X_test)

# %%
# accuracy = accuracy_score(y_test, y_pred)
# print("Accuracy:", accuracy)

# %%
test_dt_fil = test_dt.drop(['city_id', 'condition_text', 'sunrise', 'sunset'], axis=1).copy()
test_dt_fil.set_index('day_id', inplace=True)

test_dt_fil
# Out:
#         temperature_celsius  wind_kph  wind_degree  pressure_mb  precip_mm  \
# day_id
# D0001                  27.0       6.1          210       1006.0        0.0
# D0002                  22.0       6.1          170       1006.0        0.0
# D0005                  18.0       3.6           92       1019.0        0.0
# D0006                  20.0       3.6           96       1019.0        0.0
# D0008                  21.0      20.2          330       1011.0        0.0
# ...                     ...       ...          ...          ...        ...
# D2888                  19.5      16.6          113       1015.0        0.0
# D2890                  17.4      13.0           51       1017.0        0.0
# D2891                  19.2      11.5           46       1016.0        0.0
# D2892                  19.2      14.4           76       1017.0        0.0
# D2893                  18.6      17.3           61       1016.0        0.0
#
#         humidity  cloud  feels_like_celsius  visibility_km  uv_index  \
# day_id
# D0001         54     75                28.0           10.0       6.0
# D0002         73     75                24.5           10.0       1.0
# D0005         94      0                18.0           10.0       1.0
# D0006         88      0                20.0           10.0       1.0
# D0008         53     75                21.0           10.0       1.0
# ...          ...    ...                 ...            ...       ...
# D2888         38      0                19.5           10.0       1.0
# D2890         49      0                17.4           10.0       1.0
# D2891         34      0                19.2           10.0       1.0
# D2892         45      2                19.2           10.0       1.0
# D2893         34      0                18.6           10.0       1.0
#
#         gust_kph  air_quality_us-epa-index
# day_id
# D0001       11.9                         2
# D0002       23.4                         1
# D0005        9.0                         1
# D0006       11.2                         1
# D0008       17.3                         1
# ...          ...                       ...
# D2888       26.7                         1
# D2890       22.2                         1
# D2891       21.3                         2
# D2892       24.9                         2
# D2893       30.2                         2
#
# [2414 rows x 12 columns]

# %%
X_train = train_dt_fil.drop('condition_id', axis=1)
y_train = train_dt_fil['condition_id']

X_test = test_dt_fil

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# %%
test_dt_fil['condition_id'] = y_pred
test_dt_fil
# Out:
#         temperature_celsius  wind_kph  wind_degree  pressure_mb  precip_mm  \
# day_id
# D0001                  27.0       6.1          210       1006.0        0.0
# D0002                  22.0       6.1          170       1006.0        0.0
# D0005                  18.0       3.6           92       1019.0        0.0
# D0006                  20.0       3.6           96       1019.0        0.0
# D0008                  21.0      20.2          330       1011.0        0.0
# ...                     ...       ...          ...          ...        ...
# D2888                  19.5      16.6          113       1015.0        0.0
# D2890                  17.4      13.0           51       1017.0        0.0
# D2891                  19.2      11.5           46       1016.0        0.0
# D2892                  19.2      14.4           76       1017.0        0.0
# D2893                  18.6      17.3           61       1016.0        0.0
#
#         humidity  cloud  feels_like_celsius  visibility_km  uv_index  \
# day_id
# D0001         54     75                28.0           10.0       6.0
# D0002         73     75                24.5           10.0       1.0
# D0005         94      0                18.0           10.0       1.0
# D0006         88      0                20.0           10.0       1.0
# D0008         53     75                21.0           10.0       1.0
# ...          ...    ...                 ...            ...       ...
# D2888         38      0                19.5           10.0       1.0
# D2890         49      0                17.4           10.0       1.0
# D2891         34      0                19.2           10.0       1.0
# D2892         45      2                19.2           10.0       1.0
# D2893         34      0                18.6           10.0       1.0
#
#         gust_kph  air_quality_us-epa-index  condition_id
# day_id
# D0001       11.9                         2             2
# D0002       23.4                         1             2
# D0005        9.0                         1             1
# D0006       11.2                         1             1
# D0008       17.3                         1             2
# ...          ...                       ...           ...
# D2888       26.7                         1             1
# D2890       22.2                         1             1
# D2891       21.3                         2             1
# D2892       24.9                         2             1
# D2893       30.2                         2             1
#
# [2414 rows x 13 columns]

# %%
test_dt_res = test_dt_fil.copy()
test_dt_res.reset_index(inplace=True, drop=False)
test_dt_res
# Out:
#      day_id  temperature_celsius  wind_kph  wind_degree  pressure_mb  \
# 0     D0001                 27.0       6.1          210       1006.0
# 1     D0002                 22.0       6.1          170       1006.0
# 2     D0005                 18.0       3.6           92       1019.0
# 3     D0006                 20.0       3.6           96       1019.0
# 4     D0008                 21.0      20.2          330       1011.0
# ...     ...                  ...       ...          ...          ...
# 2409  D2888                 19.5      16.6          113       1015.0
# 2410  D2890                 17.4      13.0           51       1017.0
# 2411  D2891                 19.2      11.5           46       1016.0
# 2412  D2892                 19.2      14.4           76       1017.0
# 2413  D2893                 18.6      17.3           61       1016.0
#
#       precip_mm  humidity  cloud  feels_like_celsius  visibility_km  uv_index  \
# 0           0.0        54     75                28.0           10.0       6.0
# 1           0.0        73     75                24.5           10.0       1.0
# 2           0.0        94      0                18.0           10.0       1.0
# 3           0.0        88      0                20.0           10.0       1.0
# 4           0.0        53     75                21.0           10.0       1.0
# ...         ...       ...    ...                 ...            ...       ...
# 2409        0.0        38      0                19.5           10.0       1.0
# 2410        0.0        49      0                17.4           10.0       1.0
# 2411        0.0        34      0                19.2           10.0       1.0
# 2412        0.0        45      2                19.2           10.0       1.0
# 2413        0.0        34      0                18.6           10.0       1.0
#
#       gust_kph  air_quality_us-epa-index  condition_id
# 0         11.9                         2             2
# 1         23.4                         1             2
# 2          9.0                         1             1
# 3         11.2                         1             1
# 4         17.3                         1             2
# ...        ...                       ...           ...
# 2409      26.7                         1             1
# 2410      22.2                         1             1
# 2411      21.3                         2             1
# 2412      24.9                         2             1
# 2413      30.2                         2             1
#
# [2414 rows x 14 columns]

# %%
test_dt_res['condition_text'] = test_dt_res['condition_id'].apply(lambda x: cond_strngs[x])
test_dt_res
# Out:
#      day_id  temperature_celsius  wind_kph  wind_degree  pressure_mb  \
# 0     D0001                 27.0       6.1          210       1006.0
# 1     D0002                 22.0       6.1          170       1006.0
# 2     D0005                 18.0       3.6           92       1019.0
# 3     D0006                 20.0       3.6           96       1019.0
# 4     D0008                 21.0      20.2          330       1011.0
# ...     ...                  ...       ...          ...          ...
# 2409  D2888                 19.5      16.6          113       1015.0
# 2410  D2890                 17.4      13.0           51       1017.0
# 2411  D2891                 19.2      11.5           46       1016.0
# 2412  D2892                 19.2      14.4           76       1017.0
# 2413  D2893                 18.6      17.3           61       1016.0
#
#       precip_mm  humidity  cloud  feels_like_celsius  visibility_km  uv_index  \
# 0           0.0        54     75                28.0           10.0       6.0
# 1           0.0        73     75                24.5           10.0       1.0
# 2           0.0        94      0                18.0           10.0       1.0
# 3           0.0        88      0                20.0           10.0       1.0
# 4           0.0        53     75                21.0           10.0       1.0
# ...         ...       ...    ...                 ...            ...       ...
# 2409        0.0        38      0                19.5           10.0       1.0
# 2410        0.0        49      0                17.4           10.0       1.0
# 2411        0.0        34      0                19.2           10.0       1.0
# 2412        0.0        45      2                19.2           10.0       1.0
# 2413        0.0        34      0                18.6           10.0       1.0
#
#       gust_kph  air_quality_us-epa-index  condition_id   condition_text
# 0         11.9                         2             2    Partly Cloudy
# 1         23.4                         1             2    Partly Cloudy
# 2          9.0                         1             1  Clear and Sunny
# 3         11.2                         1             1  Clear and Sunny
# 4         17.3                         1             2    Partly Cloudy
# ...        ...                       ...           ...              ...
# 2409      26.7                         1             1  Clear and Sunny
# 2410      22.2                         1             1  Clear and Sunny
# 2411      21.3                         2             1  Clear and Sunny
# 2412      24.9                         2             1  Clear and Sunny
# 2413      30.2                         2             1  Clear and Sunny
#
# [2414 rows x 15 columns]

# %%
train_dt_res = train_dt.drop(['city_id', 'sunrise', 'sunset'], axis=1).copy()
train_dt_res.reset_index(inplace=True, drop=False)
train_dt_res
# Out:
#      index day_id  temperature_celsius           condition_text  wind_kph  \
# 0        2  D0003                 20.0  Light Rain with Thunder       3.6
# 1        3  D0004                 17.0          Clear and Sunny       6.1
# 2        6  D0007                 21.0            Partly Cloudy       4.0
# 3       18  D0019                 19.0          Clear and Sunny       3.6
# 4       27  D0028                 19.0            Partly Cloudy       3.6
# ..     ...    ...                  ...                      ...       ...
# 474   2838  D2839                 27.0            Partly Cloudy      19.1
# 475   2863  D2864                 21.4      Light Precipitation       3.6
# 476   2873  D2874                 16.9          Clear and Sunny      16.6
# 477   2886  D2887                 19.5          Clear and Sunny       5.4
# 478   2888  D2889                 17.1          Clear and Sunny      13.3
#
#      wind_degree  pressure_mb  precip_mm  humidity  cloud  feels_like_celsius  \
# 0             10       1011.0       4.50       100     75                20.0
# 1            150       1018.0       0.00        88      0                17.0
# 2            310       1015.0       0.00       100     50                21.0
# 3             64       1017.0       0.00        88      0                19.0
# 4             83       1010.0       0.00        73     25                19.0
# ..           ...          ...        ...       ...    ...                 ...
# 474           90       1014.0       0.01        70     25                29.8
# 475          178       1012.0       0.00        89     75                21.4
# 476           68       1018.0       0.00        44      2                16.9
# 477           27       1014.0       0.00        34      0                19.4
# 478           61       1017.0       0.00        57      3                17.1
#
#      visibility_km  uv_index  gust_kph  air_quality_us-epa-index  condition_id
# 0             10.0       1.0      12.6                         1             0
# 1             10.0       1.0      11.2                         1             1
# 2             10.0       1.0      15.1                         2             2
# 3             10.0       1.0       8.3                         3             1
# 4             10.0       1.0       8.3                         1             2
# ..             ...       ...       ...                       ...           ...
# 474           10.0       6.0      45.6                         1             2
# 475           10.0       6.0       6.6                         1             3
# 476           10.0       1.0      27.0                         1             1
# 477           10.0       1.0      11.2                         2             1
# 478           10.0       1.0      22.2                         1             1
#
# [479 rows x 16 columns]

# %%
fin_data_1 = train_dt_res[['day_id', 'condition_text']].copy()
fin_data_2 = test_dt_res[['day_id', 'condition_text']].copy()

fin_data = pd.concat([fin_data_1, fin_data_2])
fin_data.reset_index(inplace=True, drop=True)
fin_data
# Out:
#      day_id           condition_text
# 0     D0003  Light Rain with Thunder
# 1     D0004          Clear and Sunny
# 2     D0007            Partly Cloudy
# 3     D0019          Clear and Sunny
# 4     D0028            Partly Cloudy
# ...     ...                      ...
# 2888  D2888          Clear and Sunny
# 2889  D2890          Clear and Sunny
# 2890  D2891          Clear and Sunny
# 2891  D2892          Clear and Sunny
# 2892  D2893          Clear and Sunny
#
# [2893 rows x 2 columns]

# %%
fin_data.to_csv('./results/3rd_res.csv', index=False)
